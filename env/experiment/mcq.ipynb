# %%
# %pip install pandas
import os
import json
import pandas as pd
import traceback
# Out:
# Requirement already satisfied: pandas in c:\users\arjun\mcqgen\env\lib\site-packages (2.3.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\arjun\mcqgen\env\lib\site-packages (from pandas) (2.3.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\arjun\mcqgen\env\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\arjun\mcqgen\env\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\arjun\mcqgen\env\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\arjun\mcqgen\env\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install langchain
# Out:
# Collecting langchain
#   Using cached langchain-1.0.8-py3-none-any.whl.metadata (4.9 kB)
# Collecting langchain-core<2.0.0,>=1.0.6 (from langchain)
#   Downloading langchain_core-1.0.7-py3-none-any.whl.metadata (3.6 kB)
# Collecting langgraph<1.1.0,>=1.0.2 (from langchain)
#   Using cached langgraph-1.0.3-py3-none-any.whl.metadata (7.8 kB)
# Collecting pydantic<3.0.0,>=2.7.4 (from langchain)
#   Using cached pydantic-2.12.4-py3-none-any.whl.metadata (89 kB)
# Collecting jsonpatch<2.0.0,>=1.33.0 (from langchain-core<2.0.0,>=1.0.6->langchain)
#   Using cached jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Collecting langsmith<1.0.0,>=0.3.45 (from langchain-core<2.0.0,>=1.0.6->langchain)
#   Downloading langsmith-0.4.44-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\arjun\mcqgen\env\lib\site-packages (from langchain-core<2.0.0,>=1.0.6->langchain) (25.0)
# Collecting pyyaml<7.0.0,>=5.3.0 (from langchain-core<2.0.0,>=1.0.6->langchain)
#   Using cached pyyaml-6.0.3-cp314-cp314-win_amd64.whl.metadata (2.4 kB)
# Collecting tenacity!=8.4.0,<10.0.0,>=8.1.0 (from langchain-core<2.0.0,>=1.0.6->langchain)
#   Using cached tenacity-9.1.2-py3-none-any.whl.metadata (1.2 kB)
# Collecting typing-extensions<5.0.0,>=4.7.0 (from langchain-core<2.0.0,>=1.0.6->langchain)
#   Using cached typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting jsonpointer>=1.9 (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.0.6->langchain)
#   Using cached jsonpointer-3.0.0-py2.py3-none-any.whl.metadata (2.3 kB)
# Collecting langgraph-checkpoint<4.0.0,>=2.1.0 (from langgraph<1.1.0,>=1.0.2->langchain)
#   Using cached langgraph_checkpoint-3.0.1-py3-none-any.whl.metadata (4.7 kB)
# Collecting langgraph-prebuilt<1.1.0,>=1.0.2 (from langgraph<1.1.0,>=1.0.2->langchain)
#   Using cached langgraph_prebuilt-1.0.4-py3-none-any.whl.metadata (5.2 kB)
# Collecting langgraph-sdk<0.3.0,>=0.2.2 (from langgraph<1.1.0,>=1.0.2->langchain)
#   Using cached langgraph_sdk-0.2.9-py3-none-any.whl.metadata (1.5 kB)
# Collecting xxhash>=3.5.0 (from langgraph<1.1.0,>=1.0.2->langchain)
#   Using cached xxhash-3.6.0-cp314-cp314-win_amd64.whl.metadata (13 kB)
# Collecting ormsgpack>=1.12.0 (from langgraph-checkpoint<4.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.2->langchain)
#   Using cached ormsgpack-1.12.0-cp314-cp314-win_amd64.whl.metadata (1.2 kB)
# Collecting httpx>=0.25.2 (from langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain)
#   Using cached httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting orjson>=3.10.1 (from langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain)
#   Using cached orjson-3.11.4-cp314-cp314-win_amd64.whl.metadata (42 kB)
# Collecting requests-toolbelt>=1.0.0 (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.6->langchain)
#   Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Collecting requests>=2.0.0 (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.6->langchain)
#   Using cached requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Collecting zstandard>=0.23.0 (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.6->langchain)
#   Using cached zstandard-0.25.0-cp314-cp314-win_amd64.whl.metadata (3.3 kB)
# Collecting anyio (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain)
#   Using cached anyio-4.11.0-py3-none-any.whl.metadata (4.1 kB)
# Collecting certifi (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain)
#   Using cached certifi-2025.11.12-py3-none-any.whl.metadata (2.5 kB)
# Collecting httpcore==1.* (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain)
#   Using cached httpcore-1.0.9-py3-none-any.whl.metadata (21 kB)
# Collecting idna (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain)
#   Using cached idna-3.11-py3-none-any.whl.metadata (8.4 kB)
# Collecting h11>=0.16 (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain)
#   Using cached h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# Collecting annotated-types>=0.6.0 (from pydantic<3.0.0,>=2.7.4->langchain)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.41.5 (from pydantic<3.0.0,>=2.7.4->langchain)
#   Using cached pydantic_core-2.41.5-cp314-cp314-win_amd64.whl.metadata (7.4 kB)
# Collecting typing-inspection>=0.4.2 (from pydantic<3.0.0,>=2.7.4->langchain)
#   Using cached typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Collecting charset_normalizer<4,>=2 (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.6->langchain)
#   Using cached charset_normalizer-3.4.4-cp314-cp314-win_amd64.whl.metadata (38 kB)
# Collecting urllib3<3,>=1.21.1 (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.6->langchain)
#   Using cached urllib3-2.5.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting sniffio>=1.1 (from anyio->httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain)
#   Using cached sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Using cached langchain-1.0.8-py3-none-any.whl (93 kB)
# Downloading langchain_core-1.0.7-py3-none-any.whl (472 kB)
# Using cached jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Using cached langgraph-1.0.3-py3-none-any.whl (156 kB)
# Using cached langgraph_checkpoint-3.0.1-py3-none-any.whl (46 kB)
# Using cached langgraph_prebuilt-1.0.4-py3-none-any.whl (34 kB)
# Using cached langgraph_sdk-0.2.9-py3-none-any.whl (56 kB)
# Downloading langsmith-0.4.44-py3-none-any.whl (410 kB)
# Using cached httpx-0.28.1-py3-none-any.whl (73 kB)
# Using cached httpcore-1.0.9-py3-none-any.whl (78 kB)
# Using cached pydantic-2.12.4-py3-none-any.whl (463 kB)
# Using cached pydantic_core-2.41.5-cp314-cp314-win_amd64.whl (2.0 MB)
# Using cached pyyaml-6.0.3-cp314-cp314-win_amd64.whl (156 kB)
# Using cached tenacity-9.1.2-py3-none-any.whl (28 kB)
# Using cached typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Using cached h11-0.16.0-py3-none-any.whl (37 kB)
# Using cached jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Using cached orjson-3.11.4-cp314-cp314-win_amd64.whl (131 kB)
# Using cached ormsgpack-1.12.0-cp314-cp314-win_amd64.whl (113 kB)
# Using cached requests-2.32.5-py3-none-any.whl (64 kB)
# Using cached charset_normalizer-3.4.4-cp314-cp314-win_amd64.whl (107 kB)
# Using cached idna-3.11-py3-none-any.whl (71 kB)
# Using cached urllib3-2.5.0-py3-none-any.whl (129 kB)
# Using cached certifi-2025.11.12-py3-none-any.whl (159 kB)
# Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Using cached typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Using cached xxhash-3.6.0-cp314-cp314-win_amd64.whl (32 kB)
# Using cached zstandard-0.25.0-cp314-cp314-win_amd64.whl (516 kB)
# Using cached anyio-4.11.0-py3-none-any.whl (109 kB)
# Using cached sniffio-1.3.1-py3-none-any.whl (10 kB)
# Installing collected packages: zstandard, xxhash, urllib3, typing-extensions, tenacity, sniffio, pyyaml, ormsgpack, orjson, jsonpointer, idna, h11, charset_normalizer, certifi, annotated-types, typing-inspection, requests, pydantic-core, jsonpatch, httpcore, anyio, requests-toolbelt, pydantic, httpx, langsmith, langgraph-sdk, langchain-core, langgraph-checkpoint, langgraph-prebuilt, langgraph, langchain
#
#    - --------------------------------------  1/31 [xxhash]
#    -- -------------------------------------  2/31 [urllib3]
#    -- -------------------------------------  2/31 [urllib3]
#    -- -------------------------------------  2/31 [urllib3]
#    -- -------------------------------------  2/31 [urllib3]
#    -- -------------------------------------  2/31 [urllib3]
#    -- -------------------------------------  2/31 [urllib3]
#    -- -------------------------------------  2/31 [urllib3]
#    -- -------------------------------------  2/31 [urllib3]
#    ----- ----------------------------------  4/31 [tenacity]
#    ----- ----------------------------------  4/31 [tenacity]
#    ------ ---------------------------------  5/31 [sniffio]
#    ------- --------------------------------  6/31 [pyyaml]
#    ------- --------------------------------  6/31 [pyyaml]
#    ------- --------------------------------  6/31 [pyyaml]
#    ------- --------------------------------  6/31 [pyyaml]
#    ---------- -----------------------------  8/31 [orjson]
#    ------------ --------------------------- 10/31 [idna]
#    ------------ --------------------------- 10/31 [idna]
#    ------------ --------------------------- 10/31 [idna]
#    -------------- ------------------------- 11/31 [h11]
#    -------------- ------------------------- 11/31 [h11]
#    -------------- ------------------------- 11/31 [h11]
#    -------------- ------------------------- 11/31 [h11]
#    --------------- ------------------------ 12/31 [charset_normalizer]
#    --------------- ------------------------ 12/31 [charset_normalizer]
#    --------------- ------------------------ 12/31 [charset_normalizer]
#    --------------- ------------------------ 12/31 [charset_normalizer]
#    --------------- ------------------------ 12/31 [charset_normalizer]
#    ---------------- ----------------------- 13/31 [certifi]
#    ------------------- -------------------- 15/31 [typing-inspection]
#    -------------------- ------------------- 16/31 [requests]
#    -------------------- ------------------- 16/31 [requests]
#    -------------------- ------------------- 16/31 [requests]
#    --------------------- ------------------ 17/31 [pydantic-core]
#    ----------------------- ---------------- 18/31 [jsonpatch]
#    ------------------------ --------------- 19/31 [httpcore]
#    ------------------------ --------------- 19/31 [httpcore]
#    ------------------------ --------------- 19/31 [httpcore]
#    ------------------------ --------------- 19/31 [httpcore]
#    ------------------------ --------------- 19/31 [httpcore]
#    ------------------------ --------------- 19/31 [httpcore]
#    ------------------------ --------------- 19/31 [httpcore]
#    ------------------------- -------------- 20/31 [anyio]
#    ------------------------- -------------- 20/31 [anyio]
#    ------------------------- -------------- 20/31 [anyio]
#    ------------------------- -------------- 20/31 [anyio]
#    ------------------------- -------------- 20/31 [anyio]
#    ------------------------- -------------- 20/31 [anyio]
#    ------------------------- -------------- 20/31 [anyio]
#    ------------------------- -------------- 20/31 [anyio]
#    ------------------------- -------------- 20/31 [anyio]
#    --------------------------- ------------ 21/31 [requests-toolbelt]
#    --------------------------- ------------ 21/31 [requests-toolbelt]
#    --------------------------- ------------ 21/31 [requests-toolbelt]
#    --------------------------- ------------ 21/31 [requests-toolbelt]
#    --------------------------- ------------ 21/31 [requests-toolbelt]
#    --------------------------- ------------ 21/31 [requests-toolbelt]
#    ---------------------------- ----------- 22/31 [pydantic]
#    ---------------------------- ----------- 22/31 [pydantic]
#    ---------------------------- ----------- 22/31 [pydantic]
#    ---------------------------- ----------- 22/31 [pydantic]
#    ---------------------------- ----------- 22/31 [pydantic]
#    ---------------------------- ----------- 22/31 [pydantic]
#    ---------------------------- ----------- 22/31 [pydantic]
#    ---------------------------- ----------- 22/31 [pydantic]
#    ---------------------------- ----------- 22/31 [pydantic]
#    ---------------------------- ----------- 22/31 [pydantic]
#    ---------------------------- ----------- 22/31 [pydantic]
#    ---------------------------- ----------- 22/31 [pydantic]
#    ---------------------------- ----------- 22/31 [pydantic]
#    ---------------------------- ----------- 22/31 [pydantic]
#    ---------------------------- ----------- 22/31 [pydantic]
#    ---------------------------- ----------- 22/31 [pydantic]
#    ---------------------------- ----------- 22/31 [pydantic]
#    ---------------------------- ----------- 22/31 [pydantic]
#    ---------------------------- ----------- 22/31 [pydantic]
#    ---------------------------- ----------- 22/31 [pydantic]
#    ---------------------------- ----------- 22/31 [pydantic]
#    ---------------------------- ----------- 22/31 [pydantic]
#    ---------------------------- ----------- 22/31 [pydantic]
#    ---------------------------- ----------- 22/31 [pydantic]
#    ----------------------------- ---------- 23/31 [httpx]
#    ----------------------------- ---------- 23/31 [httpx]
#    ----------------------------- ---------- 23/31 [httpx]
#    ----------------------------- ---------- 23/31 [httpx]
#    ----------------------------- ---------- 23/31 [httpx]
#    ----------------------------- ---------- 23/31 [httpx]
#    ----------------------------- ---------- 23/31 [httpx]
#    ------------------------------ --------- 24/31 [langsmith]
#    ------------------------------ --------- 24/31 [langsmith]
#    ------------------------------ --------- 24/31 [langsmith]
#    ------------------------------ --------- 24/31 [langsmith]
#    ------------------------------ --------- 24/31 [langsmith]
#    ------------------------------ --------- 24/31 [langsmith]
#    ------------------------------ --------- 24/31 [langsmith]
#    ------------------------------ --------- 24/31 [langsmith]
#    ------------------------------ --------- 24/31 [langsmith]
#    ------------------------------ --------- 24/31 [langsmith]
#    ------------------------------ --------- 24/31 [langsmith]
#    ------------------------------ --------- 24/31 [langsmith]
#    ------------------------------ --------- 24/31 [langsmith]
#    ------------------------------ --------- 24/31 [langsmith]
#    -------------------------------- ------- 25/31 [langgraph-sdk]
#    -------------------------------- ------- 25/31 [langgraph-sdk]
#    --------------------------------- ------ 26/31 [langchain-core]
#    --------------------------------- ------ 26/31 [langchain-core]
#    --------------------------------- ------ 26/31 [langchain-core]
#    --------------------------------- ------ 26/31 [langchain-core]
#    --------------------------------- ------ 26/31 [langchain-core]
#    --------------------------------- ------ 26/31 [langchain-core]
#    --------------------------------- ------ 26/31 [langchain-core]
#    --------------------------------- ------ 26/31 [langchain-core]
#    --------------------------------- ------ 26/31 [langchain-core]
#    --------------------------------- ------ 26/31 [langchain-core]
#    --------------------------------- ------ 26/31 [langchain-core]
#    --------------------------------- ------ 26/31 [langchain-core]
#    --------------------------------- ------ 26/31 [langchain-core]
#    --------------------------------- ------ 26/31 [langchain-core]
#    --------------------------------- ------ 26/31 [langchain-core]
#    --------------------------------- ------ 26/31 [langchain-core]
#    --------------------------------- ------ 26/31 [langchain-core]
#    --------------------------------- ------ 26/31 [langchain-core]
#    --------------------------------- ------ 26/31 [langchain-core]
#    --------------------------------- ------ 26/31 [langchain-core]
#    --------------------------------- ------ 26/31 [langchain-core]
#    --------------------------------- ------ 26/31 [langchain-core]
#    --------------------------------- ------ 26/31 [langchain-core]
#    --------------------------------- ------ 26/31 [langchain-core]
#    --------------------------------- ------ 26/31 [langchain-core]
#    --------------------------------- ------ 26/31 [langchain-core]
#    --------------------------------- ------ 26/31 [langchain-core]
#    --------------------------------- ------ 26/31 [langchain-core]
#    --------------------------------- ------ 26/31 [langchain-core]
#    --------------------------------- ------ 26/31 [langchain-core]
#    --------------------------------- ------ 26/31 [langchain-core]
#    --------------------------------- ------ 26/31 [langchain-core]
#    --------------------------------- ------ 26/31 [langchain-core]
#    --------------------------------- ------ 26/31 [langchain-core]
#    --------------------------------- ------ 26/31 [langchain-core]
#    --------------------------------- ------ 26/31 [langchain-core]
#    --------------------------------- ------ 26/31 [langchain-core]
#    ---------------------------------- ----- 27/31 [langgraph-checkpoint]
#    ---------------------------------- ----- 27/31 [langgraph-checkpoint]
#    ---------------------------------- ----- 27/31 [langgraph-checkpoint]
#    ------------------------------------ --- 28/31 [langgraph-prebuilt]
#    ------------------------------------ --- 28/31 [langgraph-prebuilt]
#    ------------------------------------- -- 29/31 [langgraph]
#    ------------------------------------- -- 29/31 [langgraph]
#    ------------------------------------- -- 29/31 [langgraph]
#    ------------------------------------- -- 29/31 [langgraph]
#    ------------------------------------- -- 29/31 [langgraph]
#    ------------------------------------- -- 29/31 [langgraph]
#    ------------------------------------- -- 29/31 [langgraph]
#    ------------------------------------- -- 29/31 [langgraph]
#    ------------------------------------- -- 29/31 [langgraph]
#    ------------------------------------- -- 29/31 [langgraph]
#    ------------------------------------- -- 29/31 [langgraph]
#    ------------------------------------- -- 29/31 [langgraph]
#    ------------------------------------- -- 29/31 [langgraph]
#    ------------------------------------- -- 29/31 [langgraph]
#    -------------------------------------- - 30/31 [langchain]
#    -------------------------------------- - 30/31 [langchain]
#    -------------------------------------- - 30/31 [langchain]
#    -------------------------------------- - 30/31 [langchain]
#    -------------------------------------- - 30/31 [langchain]
#    -------------------------------------- - 30/31 [langchain]
#    ---------------------------------------- 31/31 [langchain]
#
# Successfully installed annotated-types-0.7.0 anyio-4.11.0 certifi-2025.11.12 charset_normalizer-3.4.4 h11-0.16.0 httpcore-1.0.9 httpx-0.28.1 idna-3.11 jsonpatch-1.33 jsonpointer-3.0.0 langchain-1.0.8 langchain-core-1.0.7 langgraph-1.0.3 langgraph-checkpoint-3.0.1 langgraph-prebuilt-1.0.4 langgraph-sdk-0.2.9 langsmith-0.4.44 orjson-3.11.4 ormsgpack-1.12.0 pydantic-2.12.4 pydantic-core-2.41.5 pyyaml-6.0.3 requests-2.32.5 requests-toolbelt-1.0.0 sniffio-1.3.1 tenacity-9.1.2 typing-extensions-4.15.0 typing-inspection-0.4.2 urllib3-2.5.0 xxhash-3.6.0 zstandard-0.25.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install langchain-openai

from langchain_openai import ChatOpenAI
# Out:
# Collecting langchain-openai
#   Using cached langchain_openai-1.0.3-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: langchain-core<2.0.0,>=1.0.2 in c:\users\arjun\mcqgen\env\lib\site-packages (from langchain-openai) (1.0.7)
# Collecting openai<3.0.0,>=1.109.1 (from langchain-openai)
#   Downloading openai-2.8.1-py3-none-any.whl.metadata (29 kB)
# Collecting tiktoken<1.0.0,>=0.7.0 (from langchain-openai)
#   Downloading tiktoken-0.12.0-cp314-cp314-win_amd64.whl.metadata (6.9 kB)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\arjun\mcqgen\env\lib\site-packages (from langchain-core<2.0.0,>=1.0.2->langchain-openai) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\arjun\mcqgen\env\lib\site-packages (from langchain-core<2.0.0,>=1.0.2->langchain-openai) (0.4.44)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\arjun\mcqgen\env\lib\site-packages (from langchain-core<2.0.0,>=1.0.2->langchain-openai) (25.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\arjun\mcqgen\env\lib\site-packages (from langchain-core<2.0.0,>=1.0.2->langchain-openai) (2.12.4)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\arjun\mcqgen\env\lib\site-packages (from langchain-core<2.0.0,>=1.0.2->langchain-openai) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\arjun\mcqgen\env\lib\site-packages (from langchain-core<2.0.0,>=1.0.2->langchain-openai) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\arjun\mcqgen\env\lib\site-packages (from langchain-core<2.0.0,>=1.0.2->langchain-openai) (4.15.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\arjun\mcqgen\env\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.0.2->langchain-openai) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\arjun\mcqgen\env\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.2->langchain-openai) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\arjun\mcqgen\env\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.2->langchain-openai) (3.11.4)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\arjun\mcqgen\env\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.2->langchain-openai) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\arjun\mcqgen\env\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.2->langchain-openai) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\arjun\mcqgen\env\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.2->langchain-openai) (0.25.0)
# Requirement already satisfied: anyio in c:\users\arjun\mcqgen\env\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.2->langchain-openai) (4.11.0)
# Requirement already satisfied: certifi in c:\users\arjun\mcqgen\env\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.2->langchain-openai) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in c:\users\arjun\mcqgen\env\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.2->langchain-openai) (1.0.9)
# Requirement already satisfied: idna in c:\users\arjun\mcqgen\env\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.2->langchain-openai) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\arjun\mcqgen\env\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.2->langchain-openai) (0.16.0)
# Collecting distro<2,>=1.7.0 (from openai<3.0.0,>=1.109.1->langchain-openai)
#   Downloading distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting jiter<1,>=0.10.0 (from openai<3.0.0,>=1.109.1->langchain-openai)
#   Downloading jiter-0.12.0-cp314-cp314-win_amd64.whl.metadata (5.3 kB)
# Requirement already satisfied: sniffio in c:\users\arjun\mcqgen\env\lib\site-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (1.3.1)
# Collecting tqdm>4 (from openai<3.0.0,>=1.109.1->langchain-openai)
#   Downloading tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\arjun\mcqgen\env\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.0.2->langchain-openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\arjun\mcqgen\env\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.0.2->langchain-openai) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\arjun\mcqgen\env\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.0.2->langchain-openai) (0.4.2)
# Collecting regex>=2022.1.18 (from tiktoken<1.0.0,>=0.7.0->langchain-openai)
#   Downloading regex-2025.11.3-cp314-cp314-win_amd64.whl.metadata (41 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\arjun\mcqgen\env\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.2->langchain-openai) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\arjun\mcqgen\env\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.2->langchain-openai) (2.5.0)
# Requirement already satisfied: colorama in c:\users\arjun\mcqgen\env\lib\site-packages (from tqdm>4->openai<3.0.0,>=1.109.1->langchain-openai) (0.4.6)
# Using cached langchain_openai-1.0.3-py3-none-any.whl (82 kB)
# Downloading openai-2.8.1-py3-none-any.whl (1.0 MB)
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    ---------------------------------------- 1.0/1.0 MB 10.4 MB/s  0:00:00
# Downloading distro-1.9.0-py3-none-any.whl (20 kB)
# Downloading jiter-0.12.0-cp314-cp314-win_amd64.whl (204 kB)
# Downloading tiktoken-0.12.0-cp314-cp314-win_amd64.whl (921 kB)
#    ---------------------------------------- 0.0/921.1 kB ? eta -:--:--
#    ---------------------------------------- 921.1/921.1 kB 18.6 MB/s  0:00:00
# Downloading regex-2025.11.3-cp314-cp314-win_amd64.whl (280 kB)
# Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
# Installing collected packages: tqdm, regex, jiter, distro, tiktoken, openai, langchain-openai
#
#    ---------------------------------------- 0/7 [tqdm]
#    ---------------------------------------- 0/7 [tqdm]
#    ---------------------------------------- 0/7 [tqdm]
#    ---------------------------------------- 0/7 [tqdm]
#    ---------------------------------------- 0/7 [tqdm]
#    ---------------------------------------- 0/7 [tqdm]
#    ---------------------------------------- 0/7 [tqdm]
#    ----- ---------------------------------- 1/7 [regex]
#    ----- ---------------------------------- 1/7 [regex]
#    ----------- ---------------------------- 2/7 [jiter]
#    ----------------- ---------------------- 3/7 [distro]
#    ----------------- ---------------------- 3/7 [distro]
#    ---------------------- ----------------- 4/7 [tiktoken]
#    ---------------------- ----------------- 4/7 [tiktoken]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------- ----------- 5/7 [openai]
#    ---------------------------------- ----- 6/7 [langchain-openai]
#    ---------------------------------- ----- 6/7 [langchain-openai]
#    ---------------------------------- ----- 6/7 [langchain-openai]
#    ---------------------------------------- 7/7 [langchain-openai]
#
# Successfully installed distro-1.9.0 jiter-0.12.0 langchain-openai-1.0.3 openai-2.8.1 regex-2025.11.3 tiktoken-0.12.0 tqdm-4.67.1
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install python-dotenv
from dotenv import load_dotenv
load_dotenv()
# Out:
# Requirement already satisfied: python-dotenv in c:\users\arjun\mcqgen\env\lib\site-packages (1.2.1)
# Note: you may need to restart the kernel to use updated packages.
# True

# %%
KEY=os.getenv("OPENAI_API_KEY")

# %%
print  (KEY)
# Out:
# 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

# %%
KEY = "your_openai_api_key_here"  # Replace with your actual OpenAI API key
llm = ChatOpenAI(openai_api_key=KEY, model_name="gpt-3.5-turbo", temperature=0.5)
response = llm.predict("Hello world")
